# %%
import pandas as pd
pd.read_table('http://www.flightstats.com/go/FlightStatus/flightStatusByAirport.do')
# Out:
#    <!-- saved from url=(0059)http://www.flightstats.com/fserror/termsofuseviolation.html -->
# 0   <html><head><meta http-equiv="Content-Type" co...
# 1                   <meta http-equiv="Content-Type...
# 2                          <title>FlightStats</title>
# 3                   <meta name="author" content="A...
# 4                   <meta name="description" conte...
# 5                   <meta name="keywords" content=...
# 6                   <link rel="stylesheet" type="t...
# 7                   <link rel="stylesheet" type="t...
# 8                                             </head>
# 9                                              <body>
# 10                        <div style="padding:20px;">
# 11                          <a href="http://www.fl...
# 12                                               <h2>
# 13                                    Scraping Policy
# 14                                              </h2>
# 15        Thank you for your interest in FlightStats.
# ...
